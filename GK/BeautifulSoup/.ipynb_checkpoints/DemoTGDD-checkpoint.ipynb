# %%
import requests
import re
from bs4 import BeautifulSoup

# %%
url = "https://www.thegioididong.com/dtdd/samsung-galaxy-s22-ultra?code=0131491002959"
res = requests.get(url, headers={
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.67 Safari/537.36"
    })
soup = BeautifulSoup(res.content, features="lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="vi-VN">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Samsung Galaxy S22 Ultra 5G 128GB - Chính hãng, giá tốt
#   </title>
#   <meta content="Samsung Galaxy S22 Ultra 5G 128GB, Samsung Galaxy S22 Ultra 5G, Samsung Galaxy S22 Ultra, Samsung S22 Ultra, Galaxy S22 Ultra, S22 Ultra, Sámung S22 Ultra" name="keywords"/>
#   <meta content="Điện thoại Samsung Galaxy S22 Ultra 5G 128GB chính hãng tại TGDĐ giao nhanh, cà thẻ tại nhà, đem nhiều mẫu chọn. Bảo hành tại hơn 2000 điểm toàn quốc." name="description"/>
#   <meta content="https://www.thegioididong.com/dtdd/samsung-galaxy-s22-ultra" itemprop="url" property="og:url"/>
#   <meta content="Samsung Galaxy S22 Ultra 5G 128GB - Chính hãng, giá tốt" property="og:title"/>
# ...

# %%
product = {}

# %%
name = soup.find("h1")
product["name"] = name.string 
print(name)
print(product["name"])
# Out:
# <h1>Điện thoại Samsung Galaxy S22 Ultra 5G 128GB</h1>
# Điện thoại Samsung Galaxy S22 Ultra 5G 128GB

# %%
color = soup.find(name ="a", attrs={"data-color": True, "class": "box03__item item act"})
product["color"] = color.string
print(color)
print(product["color"])
# Out:
# <a class="box03__item item act" data-code="0131491002959" data-color="2" href="/dtdd/samsung-galaxy-s22-ultra?code=0131491002959">Đỏ</a>
# Đỏ

# %%
model = soup.find(name= "a", attrs={"data-index": True, "class": "box03__item item act"}, href=re.compile("^/dtdd"))
product["model"] = model.string
print(model)
print(product["model"])
# Out:
# <a class="box03__item item act" data-index="0" href="/dtdd/samsung-galaxy-s22-ultra">8GB/128GB</a>
# 8GB/128GB

# %%
price = soup.find(name= "p", attrs={"class": "box-price-present"})
product["price"] = price.string
print(price)
print(product["price"])
# Out:
# <p class="box-price-present">30.990.000₫ </p>
# 30.990.000₫

# %%
parameters = soup.select_one("ul.parameter__list").find_all("li")

for parameter in parameters:
    key = parameter.select_one("p.lileft").string
    value = ""
    for string in parameter.select_one("div.liright").stripped_strings:
        value = value + string + ", "
    value = value[:-2]
    product[key] = value
    print("%s %s" % (key,value))
# Out:
# Màn hình: Dynamic AMOLED 2X, 6.8", Quad HD+ (2K+)
# Hệ điều hành: Android 12
# Camera sau: Chính 108 MP & Phụ 12 MP, 10 MP, 10 MP
# Camera trước: 40 MP
# Chip: Snapdragon 8 Gen 1 8 nhân
# RAM: 8 GB
# Bộ nhớ trong: 128 GB
# SIM: 2 Nano SIM hoặc 1 Nano SIM + 1 eSIM, Hỗ trợ 5G
# Pin, Sạc: 5000 mAh, 45 W

# %%
print(product)
# Out:
# {'name': 'Điện thoại Samsung Galaxy S22 Ultra 5G 128GB', 'color': 'Đỏ', 'model': '8GB/128GB', 'price': '30.990.000₫ ', 'Màn hình:': 'Dynamic AMOLED 2X, 6.8", Quad HD+ (2K+)', 'Hệ điều hành:': 'Android 12', 'Camera sau:': 'Chính 108 MP & Phụ 12 MP, 10 MP, 10 MP', 'Camera trước:': '40 MP', 'Chip:': 'Snapdragon 8 Gen 1 8 nhân', 'RAM:': '8 GB', 'Bộ nhớ trong:': '128 GB', 'SIM:': '2 Nano SIM hoặc 1 Nano SIM + 1 eSIM, Hỗ trợ 5G', 'Pin, Sạc:': '5000 mAh, 45 W'}
