# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)

# %%
import requests
import json
import csv
import re
from bs4 import BeautifulSoup
phone_page_url = "https://tiki.vn/api/v2/products?limit=48&include=advertisement&aggregations=1&category=1795&page={}&urlKey=dien-thoai"
product_url = "https://tiki.vn/api/v2/products/{}"

product_id_file = "./product-id.txt"
product_data_file = "./product.txt"
product_file = "./product.csv"
headers = {"user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_1_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.96 Safari/537.36"}

# %%
def crawl_product_id():
    product_list = []
    i = 1
    while (True):
        print("Crawl page: ", i)
        print(phone_page_url.format(i))
        response = requests.get(phone_page_url.format(i), headers=headers)
        
        if (response.status_code != 200):
            break

        products = json.loads(response.text)["data"]

        if (len(products) == 0):
            break

        for product in products:
            product_id = str(product["id"])
            print("Product ID: ", product_id)
            product_list.append(product_id)

        i += 1

    return product_list, i

def save_product_id(product_list=[]):
    file = open(product_id_file, "w+")
    str = "\n".join(product_list)
    file.write(str)
    file.close()
    print("Save file: ", product_id_file)

# crawl product id
product_list, page = crawl_product_id()

print("No. Page: ", page)
print("No. Product ID: ", len(product_list))

# save product id for backup
save_product_id(product_list)
# Out:
# Crawl page:  1
# https://tiki.vn/api/v2/products?limit=48&include=advertisement&aggregations=1&category=1795&page=1&urlKey=phone
# Product ID:  122074543
# Product ID:  123547395
# Product ID:  123554528
# Product ID:  142667084
# Product ID:  172998120
# Product ID:  123554518
# Product ID:  142545270
# Product ID:  123554545
# Product ID:  121790468
# Product ID:  120450353
# Product ID:  123835560
# Product ID:  123565891
# Product ID:  170580388
# Product ID:  112329147
# Product ID:  123547396
# Product ID:  170497385
# Product ID:  57809866
# Product ID:  59519631
# Product ID:  88255880
# Product ID:  170581659
# Product ID:  175967811
# Product ID:  123345348
# Product ID:  128865871
# Product ID:  133578350
# Product ID:  74489817
# Product ID:  103046198
# Product ID:  123348908
# Product ID:  164937168
# Product ID:  123554520
# Product ID:  89888994
# Product ID:  141122642
# Product ID:  127076431
# Product ID:  173383634
# Product ID:  125590981
# Product ID:  168365980
# Product ID:  155339564
# Product ID:  120295859
# Product ID:  113569117
# Product ID:  140184098
# Product ID:  102077313
# Product ID:  171292910
# Product ID:  160801738
# Product ID:  170775712
# Product ID:  81027831
# Product ID:  123547404
# Product ID:  160819119
# Product ID:  109516584
# Product ID:  98895393
# Crawl page:  2
# https://tiki.vn/api/v2/products?limit=48&include=advertisement&aggregations=1&category=1795&page=2&urlKey=phone
# Product ID:  168304456
# Product ID:  123554519
# Product ID:  99862142
# Product ID:  147969070
# Product ID:  68693081
# Product ID:  143358429
# Product ID:  138932606
# Product ID:  138914723
# Product ID:  179438706
# Product ID:  129855867
# Product ID:  172178476
# Product ID:  160801751
# Product ID:  166034912
# Product ID:  107348438
# Product ID:  133811136
# Product ID:  115765559
# Product ID:  171190775
# Product ID:  168779173
# Product ID:  137440825
# Product ID:  168304536
# Product ID:  167495996
# Product ID:  163039754
# Product ID:  162593820
# Product ID:  171321555
# Product ID:  142545264
# Product ID:  141739233
# Product ID:  121744434
# Product ID:  133599948
# Product ID:  135322157
# Product ID:  107153659
# Product ID:  132234204
# Product ID:  127058588
# Product ID:  127058581
# Product ID:  171934203
# Product ID:  146261771
# Product ID:  135332196
# Product ID:  68165482
# Product ID:  166389506
# Product ID:  152949429
# Product ID:  169744014
# Product ID:  160819279
# Product ID:  176713246
# Product ID:  172160182
# Product ID:  129167418
# Product ID:  172340710
# Product ID:  101307851
# Product ID:  97562676
# Product ID:  172335599
# Crawl page:  3
# https://tiki.vn/api/v2/products?limit=48&include=advertisement&aggregations=1&category=1795&page
# https://tiki.vn/api/v2/products?limit=48&include=advertisement&aggregations=1&category=1795&page=8&urlKey=phone
# Product ID:  143523995
# Product ID:  174589577
# Product ID:  168006015
# Product ID:  169746566
# Product ID:  160303941
# Product ID:  169744522
# Product ID:  128124456
# Product ID:  105167708
# Product ID:  169744498
# Product ID:  145972424
# Product ID:  150735429
# Product ID:  136796629
# Product ID:  140743889
# Product ID:  169744469
# Product ID:  147426086
# Product ID:  173399087
# Product ID:  145905253
# Product ID:  158595043
# Product ID:  145751598
# Product ID:  145907337
# Product ID:  145867932
# Product ID:  147426081
# Product ID:  145751360
# Product ID:  145867907
# Product ID:  80145626
# Product ID:  162033655
# Product ID:  164444757
# Product ID:  179930699
# Product ID:  179554879
# Product ID:  181264344
# Product ID:  179930704
# Product ID:  55138557
# Product ID:  181266509
# Product ID:  179438711
# Product ID:  164436745
# Product ID:  181517965
# Product ID:  147117798
# Product ID:  179159226
# Crawl page:  9
# https://tiki.vn/api/v2/products?limit=48&include=advertisement&aggregations=1&category=1795&page=9&urlKey=phone
# No. Page:  9
# No. Product ID:  374
# Save file:  ./product-id.txt

# %%
def crawl_product(product_list=[]):
    product_detail_list = []
    for product_id in product_list:
        response = requests.get(product_url.format(product_id), headers=headers)
        if (response.status_code == 200):
            product_detail_list.append(response.text)
            print("Crawl product: ", product_id, ": ", response.status_code)
    return product_detail_list

flatten_field = [ "badges", "inventory", "categories", "rating_summary", 
                      "brand", "seller_specifications", "current_seller", "other_sellers", 
                      "configurable_options",  "configurable_products", "specifications", "product_links",
                      "services_and_promotions", "promotions", "stock_item", "installment_info" ]

def adjust_product(product):
    e = json.loads(product)
    if not e.get("id", False):
        return None

    for field in flatten_field:
        if field in e:
            e[field] = json.dumps(e[field], ensure_ascii=False).replace('\n','')

    return e

def save_raw_product(product_detail_list=[]):
    file = open(product_data_file, "w+")
    str = "\n".join(product_detail_list)
    file.write(str)
    file.close()
    print("Save file: ", product_data_file)

def load_raw_product():
    file = open(product_data_file, "r")
    return file.readlines()

def save_product_list(product_json_list):
    file = open(product_file, "w")
    csv_writer = csv.writer(file)

    count = 0
    for p in product_json_list:
        if p is not None:
            if count == 0:
                header = p.keys() 
                csv_writer.writerow(header) 
                count += 1
            csv_writer.writerow(p.values())
    file.close()
    print("Save file: ", product_file)

# %%
product_list = crawl_product(product_list)

# save product detail for backup
save_raw_product(product_list)

# product_list = load_raw_product()
# flatten detail before converting to csv
product_json_list = [adjust_product(p) for p in product_list]
# save product to csv
save_product_list(product_json_list)
# Out:
# Crawl product:  122074543 :  200
# Crawl product:  123547395 :  200
# Crawl product:  123554528 :  200
# Crawl product:  142667084 :  200
# Crawl product:  172998120 :  200
# Crawl product:  123554518 :  200
# Crawl product:  142545270 :  200
# Crawl product:  123554545 :  200
# Crawl product:  121790468 :  200
# Crawl product:  120450353 :  200
# Crawl product:  123835560 :  200
# Crawl product:  123565891 :  200
# Crawl product:  170580388 :  200
# Crawl product:  112329147 :  200
# Crawl product:  123547396 :  200
# Crawl product:  170497385 :  200
# Crawl product:  57809866 :  200
# Crawl product:  59519631 :  200
# Crawl product:  88255880 :  200
# Crawl product:  170581659 :  200
# Crawl product:  175967811 :  200
# Crawl product:  123345348 :  200
# Crawl product:  128865871 :  200
# Crawl product:  133578350 :  200
# Crawl product:  74489817 :  200
# Crawl product:  103046198 :  200
# Crawl product:  123348908 :  200
# Crawl product:  164937168 :  200
# Crawl product:  123554520 :  200
# Crawl product:  89888994 :  200
# Crawl product:  141122642 :  200
# Crawl product:  127076431 :  200
# Crawl product:  173383634 :  200
# Crawl product:  125590981 :  200
# Crawl product:  168365980 :  200
# Crawl product:  155339564 :  200
# Crawl product:  120295859 :  200
# Crawl product:  113569117 :  200
# Crawl product:  140184098 :  200
# Crawl product:  102077313 :  200
# Crawl product:  171292910 :  200
# Crawl product:  160801738 :  200
# Crawl product:  170775712 :  200
# Crawl product:  81027831 :  200
# Crawl product:  123547404 :  200
# Crawl product:  160819119 :  200
# Crawl product:  109516584 :  200
# Crawl product:  98895393 :  200
# Crawl product:  168304456 :  200
# Crawl product:  123554519 :  200
# Crawl product:  99862142 :  200
# Crawl product:  147969070 :  200
# Crawl product:  68693081 :  200
# Crawl product:  143358429 :  200
# Crawl product:  138932606 :  200
# Crawl product:  138914723 :  200
# Crawl product:  179438706 :  200
# Crawl product:  129855867 :  200
# Crawl product:  172178476 :  200
# Crawl product:  160801751 :  200
# Crawl product:  166034912 :  200
# Crawl product:  107348438 :  200
# Crawl product:  133811136 :  200
# Crawl product:  115765559 :  200
# Crawl product:  171190775 :  200
# Crawl product:  168779173 :  200
# Crawl product:  137440825 :  200
# Crawl product:  168304536 :  200
# Crawl product:  167495996 :  200
# Crawl product:  163039754 :  200
# Crawl product:  162593820 :  200
# Crawl product:  171321555 :  200
# Crawl product:  142545264 :  200
# Crawl product:  141739233 :  200
# Crawl product:  121744434 :  200
# Crawl product:  133599948 :  200
# Crawl product:  135322157 :  200
# Crawl product:  107153659 :  200
# Crawl product:  132234204 :  200
# Crawl product:  127058588 :  200
# Crawl product:  127058581 :  200
# Crawl product:  171934203 :  200
# Crawl product:  146261771 :  200
# Crawl product:  135332196 :  200
# Crawl product:  68165482 :  200
# Crawl product:  166389506 :  200
# Crawl product:  152949429 :  200
# Crawl product:  169744014 :  200
# Crawl product:  160819279 :  200
# Crawl product:  176713246 :  200
# Crawl product:  172160182 :  200
# Crawl product:  129167418 :  200
# Crawl product:  172340710 :  200
# Crawl product:  101307851 :  200
# Crawl product:  97562676 :  200
# Crawl product:  172335599 :  200
# Crawl product:  112821872 :  200
# Crawl product:  137572223 :  200
# Crawl product:  129558409 :  200
# Crawl product:  123565899 :  200
# Crawl product:  169547788 :  200
# Crawl product:  74935377 :  200
# Crawl product:  101615454 :  200
# Crawl product:  142419641 :  200
# Crawl product:  166438257 :  200
# Crawl product:  158741127 :  200
# Crawl product:  168282061 :  200
# Crawl product:  162478086 :  200
# Crawl product:  162473705 :  200
# Crawl product:  140309479 :  200
# Crawl product:  171221070 :  200
# Crawl product:  172001933 :  200
# Crawl product:  140960962 :  200
# Crawl product:  62269749 :  200
# Crawl product:  58616047 :  200
# Crawl product:  177746939 :  200
# Crawl product:  102565233 :  200
# Crawl product:  126682340 :  200
# Crawl product:  166034907 :  200
# Crawl product:  165965622 :  200
# Crawl product:  167611667 :  200
# Crawl product:  125600698 :  200
# Crawl product:  149148398 :  200
# Crawl product:  172589109 :  200
# Crawl product:  164758308 :  200
# Crawl product:  147058165 :  200
# Crawl product:  168317790 :  200
# Crawl product:  172329599 :  200
# Crawl product:  168320000 :  200
# Crawl product:  143850131 :  200
# Crawl product:  83368040 :  200
# Crawl product:  137864049 :  200
# Crawl product:  162583980 :  200
# Crawl product:  88100671 :  200
# Crawl product:  179159231 :  200
# Crawl product:  162526792 :  200
# Crawl product:  114092342 :  200
# Crawl product:  149776401 :  200
# Crawl product:  164960337 :  200
# Crawl product:  158714974 :  200
# Crawl product:  168721265 :  200
# Crawl product:  129859652 :  200
# Crawl product:  119464777 :  200
# Crawl product:  155833852 :  200
# Crawl product:  158091991 :  200
# Crawl product:  159725951 :  200
# Crawl product:  142419452 :  200
# Crawl product:  140221779 :  200
# Crawl product:  129866890 :  200
# Crawl product:  119461456 :  200
# Crawl product:  173164387 :  200
# Crawl product:  152880374 :  200
# Crawl product:  129167166 :  200
# Crawl product:  136975373 :  200
# Crawl product:  58065346 :  200
# Crawl product:  172334001 :  200
# Crawl product:  171254543 :  200
# Crawl product:  175193503 :  200
# Crawl product:  141418024 :  200
# Crawl product:  138305946 :  200
# Crawl product:  125595055 :  200
# Crawl product:  126051025 :  200
# Crawl product:  168183442 :  200
# Crawl product:  115830124 :  200
# Crawl product:  81034656 :  200
# Crawl product:  173764601 :  200
# Crawl product:  159110705 :  200
# Crawl product:  171897574 :  200
# Crawl product:  130744724 :  200
# Crawl product:  169746571 :  200
# Crawl product:  137203873 :  200
# Crawl product:  172303189 :  200
# Crawl product:  163149268 :  200
# Crawl product:  126296983 :  200
# Crawl product:  143847698 :  200
# Crawl product:  168520983 :  200
# Crawl product:  172313857 :  200
# Crawl product:  144162614 :  200
# Crawl product:  125766378 :  200
# Crawl product:  93502532 :  200
# Crawl product:  163149266 :  200
# Crawl product:  159853930 :  200
# Crawl product:  126219116 :  200
# Crawl product:  171117665 :  200
# Crawl product:  70661051 :  200
# Crawl product:  168721292 :  200
# Crawl product:  108202051 :  200
# Crawl product:  162593136 :  200
# Crawl product:  97562656 :  200
# Crawl product:  171323116 :  200
# Crawl product:  127061391 :  200
# Crawl product:  67910637 :  200
# Crawl product:  84715674 :  200
# Crawl product:  169520871 :  200
# Crawl product:  167267098 :  200
# Crawl product:  178575037 :  200
# Crawl product:  129859725 :  200
# Crawl product:  140146799 :  200
# Crawl product:  174878191 :  200
# Crawl product:  73509365 :  200
# Crawl product:  129868798 :  200
# Crawl product:  129559058 :  200
# Crawl product:  145854206 :  200
# Crawl product:  179717941 :  200
# Crawl product:  143384981 :  200
# Crawl product:  172309326 :  200
# Crawl product:  120135792 :  200
# Crawl product:  151588148 :  200
# Crawl product:  175424428 :  200
# Crawl product:  168055450 :  200
# Crawl product:  168094334 :  200
# Crawl product:  172670979 :  200
# Crawl product:  143359355 :  200
# Crawl product:  23258088 :  200
# Crawl product:  136383784 :  200
# Crawl product:  178000116 :  200
# Crawl product:  74492306 :  200
# Crawl product:  179589103 :  200
# Crawl product:  171121793 :  200
# Crawl product:  127076439 :  200
# Crawl product:  172949839 :  200
# Crawl product:  141133864 :  200
# Crawl product:  125769357 :  200
# Crawl product:  158880691 :  200
# Crawl product:  143274014 :  200
# Crawl product:  179591105 :  200
# Crawl product:  171169353 :  200
# Crawl product:  175192238 :  200
# Crawl product:  119421964 :  200
# Crawl product:  124877310 :  200
# Crawl product:  162728553 :  200
# Crawl product:  126050455 :  200
# Crawl product:  172175893 :  200
# Crawl product:  171121228 :  200
# Crawl product:  146887591 :  200
# Crawl product:  175147005 :  200
# Crawl product:  167952107 :  200
# Crawl product:  125755152 :  200
# Crawl product:  173764269 :  200
# Crawl product:  147877951 :  200
# Crawl product:  162198971 :  200
# Crawl product:  173390458 :  200
# Crawl product:  160797086 :  200
# Crawl product:  121252535 :  200
# Crawl product:  109421292 :  200
# Crawl product:  136980288 :  200
# Crawl product:  126730401 :  200
# Crawl product:  155924857 :  200
# Crawl product:  172826900 :  200
# Crawl product:  128446446 :  200
# Crawl product:  161158099 :  200
# Crawl product:  173205160 :  200
# Crawl product:  137582801 :  200
# Crawl product:  168844555 :  200
# Crawl product:  125771154 :  200
# Crawl product:  160372479 :  200
# Crawl product:  138873172 :  200
# Crawl product:  177141832 :  200
# Crawl product:  140144656 :  200
# Crawl product:  141529940 :  200
# Crawl product:  174422886 :  200
# Crawl product:  91616179 :  200
# Crawl product:  168953347 :  200
# Crawl product:  132221911 :  200
# Crawl product:  140163114 :  200
# Crawl product:  120450615 :  200
# Crawl product:  172555765 :  200
# Crawl product:  5868813 :  200
# Crawl product:  179234820 :  200
# Crawl product:  151463645 :  200
# Crawl product:  174593387 :  200
# Crawl product:  159733672 :  200
# Crawl product:  144142520 :  200
# Crawl product:  141419419 :  200
# Crawl product:  174890393 :  200
# Crawl product:  160799946 :  200
# Crawl product:  136999103 :  200
# Crawl product:  161178498 :  200
# Crawl product:  167967898 :  200
# Crawl product:  169744019 :  200
# Crawl product:  162574450 :  200
# Crawl product:  169756083 :  200
# Crawl product:  122171745 :  200
# Crawl product:  144870494 :  200
# Crawl product:  167015200 :  200
# Crawl product:  167219399 :  200
# Crawl product:  158348723 :  200
# Crawl product:  174649410 :  200
# Crawl product:  172828967 :  200
# Crawl product:  173764852 :  200
# Crawl product:  142245114 :  200
# Crawl product:  167349659 :  200
# Crawl product:  65492829 :  200
# Crawl product:  173450217 :  200
# Crawl product:  167383164 :  200
# Crawl product:  122171440 :  200
# Crawl product:  173219905 :  200
# Crawl product:  145371244 :  200
# Crawl product:  175167498 :  200
# Crawl product:  98891053 :  200
# Crawl product:  158461088 :  200
# Crawl product:  169304867 :  200
# Crawl product:  174630782 :  200
# Crawl product:  162574433 :  200
# Crawl product:  158808107 :  200
# Crawl product:  170338359 :  200
# Crawl product:  158895894 :  200
# Crawl product:  74750613 :  200
# Crawl product:  159887161 :  200
# Crawl product:  174598949 :  200
# Crawl product:  125755137 :  200
# Crawl product:  168940033 :  200
# Crawl product:  140747649 :  200
# Crawl product:  175175479 :  200
# Crawl product:  125245180 :  200
# Crawl product:  168779225 :  200
# Crawl product:  145367822 :  200
# Crawl product:  174599533 :  200
# Crawl product:  173392449 :  200
# Crawl product:  145554985 :  200
# Crawl product:  174604032 :  200
# Crawl product:  158895857 :  200
# Crawl product:  132068858 :  200
# Crawl product:  172319352 :  200
# Crawl product:  173712024 :  200
# Crawl product:  141496858 :  200
# Crawl product:  91616169 :  200
# Crawl product:  122074560 :  200
# Crawl product:  178951652 :  200
# Crawl product:  162201936 :  200
# Crawl product:  125755157 :  200
# Crawl product:  175174449 :  200
# Crawl product:  171592667 :  200
# Crawl product:  147438292 :  200
# Crawl product:  126730387 :  200
# Crawl product:  173711552 :  200
# Crawl product:  143523995 :  200
# Crawl product:  174589577 :  200
# Crawl product:  168006015 :  200
# Crawl product:  169746566 :  200
# Crawl product:  160303941 :  200
# Crawl product:  169744522 :  200
# Crawl product:  128124456 :  200
# Crawl product:  105167708 :  200
# Crawl product:  169744498 :  200
# Crawl product:  145972424 :  200
# Crawl product:  150735429 :  200
# Crawl product:  136796629 :  200
# Crawl product:  140743889 :  200
# Crawl product:  169744469 :  200
# Crawl product:  147426086 :  200
# Crawl product:  173399087 :  200
# Crawl product:  145905253 :  200
# Crawl product:  158595043 :  200
# Crawl product:  145751598 :  200
# Crawl product:  145907337 :  200
# Crawl product:  145867932 :  200
# Crawl product:  147426081 :  200
# Crawl product:  145751360 :  200
# Crawl product:  145867907 :  200
# Crawl product:  80145626 :  200
# Crawl product:  162033655 :  200
# Crawl product:  164444757 :  200
# Crawl product:  179930699 :  200
# Crawl product:  179554879 :  200
# Crawl product:  181264344 :  200
# Crawl product:  179930704 :  200
# Crawl product:  55138557 :  200
# Crawl product:  181266509 :  200
# Crawl product:  179438711 :  200
# Crawl product:  164436745 :  200
# Crawl product:  181517965 :  200
# Crawl product:  147117798 :  200
# Crawl product:  179159226 :  200
# Save file:  ./product.txt
# Save file:  ./product.csv
