# %%
import pandas as pd
import fuzzymatcher
import os
import re
pd.options.mode.chained_assignment = None

# %%
path = "../../res"
mapping_path = "../../res/matching"

# %%
db_table_path = "../../Database/table"
df_phones = pd.read_csv(os.path.join(db_table_path, "phones.csv"), sep =";")
df_sources = pd.read_csv(os.path.join(db_table_path, "souces.csv"), sep =";")
df_sources.astype(str)
df_phones.astype(str)

warehouse = {}
warehouse['phones'] = df_phones
warehouse['sources'] = df_sources

int_field = ["ram", "rom", "battery", "monitor_frequency", "phone_id", "int", 'price']

# %%
def getSource(souce_name, sep=";"):
    df = pd.read_csv(os.path.join(path, souce_name+".csv"), sep = sep)
    df['id'] = df.index
    df.astype(str)
    return df
def getMapping(source_name, sep=";"):
    df = pd.read_csv(os.path.join(mapping_path, source_name+".txt"), sep = sep)
    mapping = {}
    for i in range(df.shape[0]):
        mapping[df['schema'][i]] = df[source_name][i]
    return mapping

# %%
cellphones = getSource("cellphones")
mapping_cellphones = getMapping("cellphones")

hhm = getSource("hhm")
hhm['source'] = 'Hoàng Hà mobile'
mapping_hhm = getMapping("hhm")

nk = getSource("nk")
nk['source'] = 'Nguyễn Kim mobile'
mapping_nk = getMapping("nk")

# %%
def load_data(source, target, mapping):
    t = target.copy()
    for key in mapping:
        for table in t:
            t[table] = t[table].copy()
            df_table = t[table]
            if key in df_table.columns:
                target_table = df_table
        target_table[key] = source[mapping[key]]

    t['sources']['phone_id'] = source['id']
    t['phones']['id'] = source['id']
    return t

# %%
def load_match_data(source, target, id_mapping, mapping):
    t = {}
    phones = target['phones'].copy()
    sources = target['sources'].copy()
    df_not_matched = pd.DataFrame()
    df_matched = pd.DataFrame()

    df_not_matched= source[~source['id'].isin(id_mapping.keys())]
    df_matched = source[source['id'].isin(id_mapping.keys())]

    for index, row in df_matched.iterrows():
        data_row_left = {}
        for field in source.columns:
            data_row_left[field] = row[field]
        id_left = data_row_left['id']
        row_right = phones.loc[phones['id'] == id_mapping[id_left]]
        for index, row in row_right.iterrows():
            for field in phones.columns:
                if field in mapping:
                    if str(phones.at[index, field]) == 'nan':
                        phones.at[index, field] = data_row_left[mapping[field]]

        data_source = {}
        for field in sources.columns:
            if field in mapping:
                data_source[field] = (data_row_left[mapping[field]])
            elif field =='phone_id':
                data_source[field] = (id_mapping[id_left])
            else :
                data_source[field] = ("")

        data_source = pd.DataFrame([data_source])
        sources = pd.concat([sources,data_source] , axis=0, ignore_index=True)


    #if object is not exist in warehouse
    for index, row in df_not_matched.iterrows():
        data_row = {}
        for field in source.columns:
            data_row[field] = row[field]
        data_row['id'] = phones.shape[0]
        data_phone = {}
        for field in phones.columns:
            if field in mapping:
                data_phone[field] = (data_row[mapping[field]])
            elif field == 'id':
                data_phone['id'] = (data_row['id'])
            else :
                data_phone[field] = ("")

        data_source = {}
        for field in sources.columns:
            if field in mapping:
                data_source[field] = (data_row[mapping[field]])
            elif field =='phone_id':
                data_source[field] = (data_row['id'])
            else :
                data_source[field] = ("")

        data_phone = pd.DataFrame([data_phone])
        data_source = pd.DataFrame([data_source])
        phones = pd.concat([phones, data_phone] , axis=0, ignore_index=True)
        sources = pd.concat([sources,data_source] , axis=0, ignore_index=True)

    t['phones'] = phones
    t['sources'] = sources
    return t

# %%
def nomalize_data(df, mapping):
    df = df.copy()
    for key in mapping:
        if key in int_field and df[mapping[key]].dtype == 'object':
            for i in range(df.shape[0]):
                a = ''.join(filter(str.isdigit, str(df[mapping[key]][i])))
                df[mapping[key]][i] = a
    return df

# %%
def data_matching(left_df, left_col, right_df, right_col):
    df = fuzzymatcher.fuzzy_left_join(left_df, right_df, left_col, right_col, left_id_col = "id", right_id_col = "id")
    return df

# %%
def get_data_match(df_source, target, mapping, min_accept=0.5):
    if (target['phones'].shape[0] == 0) :
        return pd.DataFrame()
    target_cols = ["name", "ram", "rom"]
    source_cols = [mapping[x] for x in target_cols]
    data_match = data_matching(df_source , source_cols, target['phones'], target_cols)
    data_match = data_match.sort_values(by=['best_match_score'], ascending=False)
    data_match = data_match[data_match['best_match_score'] > min_accept]
    return data_match

# %%
def show_data_match(data_match, mapping):
   target_cols = ["name", "ram", "rom"]
   show_col = ['best_match_score', '__id_left', '__id_right']
   for col in target_cols:
      if (mapping[col] == col):
         show_col.append(col+'_left')
         show_col.append(col+'_right')
      else:
         show_col.append(col)
         show_col.append(mapping[col])

   data = data_match[data_match.columns.intersection(show_col)]
   return data

# %%
def data_maping(df_source, target, mapping, min_accept=0.5):
    df_source = nomalize_data(df_source,mapping)
    data = get_data_match(df_source, target, mapping, min_accept)

    if (data.empty):
        warehouse = load_data(df_source, target,mapping)
        return warehouse

    id_left = data['__id_left'].to_list()
    id_right = data['__id_right'].to_list()
    
    id_mapping = {}
    for i in range(len(id_left)):
        id_mapping[id_left[i]] = id_right[i]

    t = load_match_data(df_source, target, id_mapping, mapping)
    return t

# %% [markdown]
# # MAPPING DATA

# %%
warehouse = data_maping(cellphones, warehouse, mapping_cellphones)

# %%
warehouse = data_maping(hhm, warehouse, mapping_hhm)
# Out:
#       best_match_score  __id_left  __id_right  \
# 126           1.043750         20          68
# 127           0.889878         21          69
# 118           0.889184         16          65
# 116           0.849841         14          63
# 3484          0.808972        111         300
# 115           0.808545         13          62
# 107           0.806733          8          50
# 106           0.787827          7          49
# 120           0.735312         17          66
# 130           0.725221         23          71
# 128           0.724373         22          55
# 131           0.686750         24          78
# 111           0.685649         11          61
# 3145          0.652095         98         293
# 108           0.648881          9          51
# 99            0.647605          3          46
# 109           0.644353         10          60
# 117           0.643888         15          64
# 104           0.642563          6          58
# 102           0.642541          5          48
# 3150          0.640628        100         292
# 98            0.628677          2          43
# 100           0.623635          4          47
# 3146          0.579053         99         292
# 1393          0.572620         51         110
# 124           0.570655         19          72
# 122           0.569808         18          53
# 1726          0.552677         62         163
# 1391          0.541057         50         109
# 1413          0.523489         52         111
# 434           0.523428         32          20
# 4785          0.523293        146         440
#
#                                               name_left     price  \
# 126   Apple iPhone 13 Pro Max - 1TB - Chính hãng VN/...  42890000
# 127   Apple iPhone 13 Pro Max - 256GB - Chính hãng V...  31750000
# 118   Apple iPhone 13 Pro - 1TB - Chính hãng VN/A   ...  39490000
# 116   Apple iPhone 13 Mini - 512GB - Chính hãng VN/A...  26790000
# 3484  Samsung Galaxy Z Flip3 5G Flex Your Way (Phiên...  17490000
# 115   Apple iPhone 13 Mini - 256GB - Chính hãng VN/A...  21490000
# 107   Apple iPhone 12 mini - 256GB - Chính hãng VN/A...  19950000
# 106   Apple iPhone 12 mini - 128GB - Chính hãng VN/A...  15990000
# 120   Apple iPhone 13 Pro - 256GB - Chính hãng VN/A ...  29790000
# 130   Apple iPhone 13 Pro Max - Chính hãng VN/A     ...  28950000
# 128   Apple iPhone 13 Pro Max - 512GB - Chính hãng V...  36990000
# 131   Apple iPhone SE 2022 - 128GB - Chính hãng VN/A...  14490000
# 111   Apple iPhone 13 - 512GB - Chính hãng VN/A     ...  25980000
# 3145  Samsung Galaxy S21 FE (5G) - 6GB/128GB - Chính...  10990000
# 108   Apple iPhone 12 mini - Chính hãng VN/A        ...  14990000
# 99    Apple iPhone 11 - 64GB - Chính hãng VN/A      ...  11390000
# 109   Apple iPhone 13 - 256GB - Chính hãng VN/A     ...  22490000
# 117   Apple iPhone 13 Mini - Chính hãng VN/A        ...  18640000
# 104   Apple iPhone 12 - 64GB - chính hãng VN/A      ...  15890000
# 102   Apple iPhone 12 - 256GB - Chính hãng VN/A     ...  22390000
# 3150  Samsung Galaxy S21 FE (5G) - 8GB/256GB - Chính...  13650000
# 98    Apple iPhone 11 - 128GB - Chính hãng VN/A     ...  12990000
# 100   Apple iPhone 12 - 128GB - Chính hãng VN/A     ...  17590000
# 3146  Samsung Galaxy S21 FE (5G) - 8GB/128GB - Chính...  12750000
# 1393  Nokia C21 Plus 3GB/32GB - Chính hãng          ...   2690000
# 124   Apple iPhone 13 Pro - Chính hãng VN/A         ...  26750000
# 122   Apple iPhone 13 Pro - 512GB - Chính hãng VN/A ...  33890000
# 1726  OPPO Find X3 Pro 5G - Chính hãng\t            ...  18750000
# 1391  Nokia C21 Plus 2GB/64GB - Chính hãng          ...   2690000
# 1413  Nokia C21 Plus 3GB/64GB - Chính hãng          ...   2890000
# 434   Energizer Energy E20 - Chính hãng             ...    650000
# 4785  Xiaomi Redmi Note 10 Pro 8GB/128GB - Chính hãn...   5990000
#
#                                              image_left  \
# 126   https://cdn.hoanghamobile.com/i/productlist/ts...
# 127   https://cdn.hoanghamobile.com/i/productlist/ts...
# 118   https://cdn.hoanghamobile.com/i/productlist/ts...
# 116   https://cdn.hoanghamobile.com/i/productlist/ts...
# 3484  https://cdn.hoanghamobile.com/i/productlist/ts...
# 115   https://cdn.hoanghamobile.com/i/productlist/ts...
# 107   https://cdn.hoanghamobile.com/i/productlist/ts...
# 106   https://cdn.hoanghamobile.com/i/productlist/ts...
# 120   https://cdn.hoanghamobile.com/i/productlist/ts...
# 130   https://cdn.hoanghamobile.com/i/productlist/ts...
# 128   https://cdn.hoanghamobile.com/i/productlist/ts...
# 131   https://cdn.hoanghamobile.com/i/productlist/ts...
# 111   https://cdn.hoanghamobile.com/i/productlist/ts...
# 3145  https://cdn.hoanghamobile.com/i/productlist/ts...
# 108   https://cdn.hoanghamobile.com/i/productlist/ts...
# 99    https://cdn.hoanghamobile.com/i/productlist/ts...
# 109   https://cdn.hoanghamobile.com/i/productlist/ts...
# 117   https://cdn.hoanghamobile.com/i/productlist/ts...
# 104   https://cdn.hoanghamobile.com/i/productlist/ts...
# 102   https://cdn.hoanghamobile.com/i/productlist/ts...
# 3150  https://cdn.hoanghamobile.com/i/productlist/ts...
# 98    https://cdn.hoanghamobile.com/i/productlist/ts...
# 100   https://cdn.hoanghamobile.com/i/productlist/ts...
# 3146  https://cdn.hoanghamobile.com/i/productlist/ts...
# 1393  https://cdn.hoanghamobile.com/i/productlist/ts...
# 124   https://cdn.hoanghamobile.com/i/productlist/ts...
# 122   https://cdn.hoanghamobile.com/i/productlist/ts...
# 1726  https://cdn.hoanghamobile.com/i/productlist/ts...
# 1391  https://cdn.hoanghamobile.com/i/productlist/ts...
# 1413  https://cdn.hoanghamobile.com/i/productlist/ts...
# 434   https://cdn.hoanghamobile.com/i/productlist/ts...
# 4785  https://cdn.hoanghamobile.com/i/productlist/ts...
#
#                                                     url  \
# 126   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 127   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 118   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 116   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 3484  https://hoanghamobile.com/dien-thoai-di-dong/s...
# 115   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 107   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 106   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 120   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 130   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 128   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 131   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 111   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 3145  https://hoanghamobile.com/dien-thoai-di-dong/s...
# 108   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 99    https://hoanghamobile.com/dien-thoai-di-dong/i...
# 109   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 117   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 104   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 102   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 3150  https://hoanghamobile.com/dien-thoai-di-dong/s...
# 98    https://hoanghamobile.com/dien-thoai-di-dong/i...
# 100   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 3146  https://hoanghamobile.com/dien-thoai-di-dong/s...
# 1393  https://hoanghamobile.com/dien-thoai-di-dong/n...
# 124   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 122   https://hoanghamobile.com/dien-thoai-di-dong/a...
# 1726  https://hoanghamobile.com/dien-thoai-di-dong/o...
# 1391  https://hoanghamobile.com/dien-thoai-di-dong/n...
# 1413  https://hoanghamobile.com/dien-thoai-di-dong/n...
# 434   https://hoanghamobile.com/dien-thoai-di-dong/e...
# 4785  https://hoanghamobile.com/dien-thoai-di-dong/x...
#
#                                      Công nghệ màn hình  \
# 126   OLED                                          ...
# 127   OLED                                          ...
# 118   OLED                                          ...
# 116   OLED                                          ...
# 3484  Dynamic AMOLED 2X                             ...
# 115   OLED                                          ...
# 107   OLED                                          ...
# 106   OLED                                          ...
# 120   OLED                                          ...
# 130   OLED                                          ...
# 128   OLED                                          ...
# 131   IPS LCD                                       ...
# 111   OLED                                          ...
# 3145  Dynamic AMOLED 2X                             ...
# 108   OLED                                          ...
# 99    IPS LCD                                       ...
# 109   OLED                                          ...
# 117   OLED                                          ...
# 104   OLED                                          ...
# 102   OLED                                          ...
# 3150  Dynamic AMOLED 2X                             ...
# 98    IPS LCD                                       ...
# 100   OLED                                          ...
# 3146  Dynamic AMOLED 2X                             ...
# 1393  Đang cập nhật                                 ...
# 124   OLED                                          ...
# 122   OLED                                          ...
# 1726  AMOLED                                        ...
# 1391  Đang cập nhật                                 ...
# 1413  Đang cập nhật                                 ...
# 434   TFT LCD                                       ...
# 4785  AMOLED                                        ...
#
#                                            Độ phân giải  \
# 126   3 camera 12 MP  12 MP                         ...
# 127   3 camera 12 MP  12 MP                         ...
# 118   3 camera 12 MP  12 MP                         ...
# 116   2 camera 12 MP  12 MP                         ...
# 3484  2 camera 12 MP  10 MP                         ...
# 115   2 camera 12 MP  12 MP                         ...
# 107   2 camera 12 MP  12 MP                         ...
# 106   2 camera 12 MP  12 MP                         ...
# 120   3 camera 12 MP  12 MP                         ...
# 130   3 camera 12 MP  12 MP                         ...
# 128   3 camera 12 MP  12 MP                         ...
# 131   12 MP  7 MP                                   ...
# 111   2 camera 12 MP  12 MP                         ...
# 3145  Chính 12 MP & Phụ 12 MP  8 MP  32 MP          ...
# 108   2 camera 12 MP  12 MP                         ...
# 99    2 camera 12 MP  12 MP                         ...
# 109   2 camera 12 MP  12 MP                         ...
# 117   2 camera 12 MP  12 MP                         ...
# 104   2 camera 12 MP  12 MP                         ...
# 102   2 camera 12 MP  12 MP                         ...
# 3150  Chính 12 MP & Phụ 12 MP  8 MP  32 MP          ...
# 98    2 camera 12 MP  12 MP                         ...
# 100   2 camera 12 MP  12 MP                         ...
# 3146  Chính 12 MP & Phụ 12 MP  8 MP  32 MP          ...
# 1393  Đang cập nhật  Chính 13 MP & Phụ 2 MP       ...
# 124   3 camera 12 MP  12 MP                         ...
# 122   3 camera 12 MP  12 MP                         ...
# 1726  Đang cập nhật  32 MP                        ...
# 1391  Đang cập nhật  Chính 13 MP & Phụ 2 MP       ...
# 1413  Đang cập nhật  Chính 13 MP & Phụ 2 MP       ...
# 434   0.3 MP  Không                                 ...
# 4785  Chính 108 MP & Phụ 8 MP  5 MP  2 MP  16 MP    ...
#
#                       Màn hình rộng  ...  \
# 126                             NaN  ...
# 127                             NaN  ...
# 118                             NaN  ...
# 116                             NaN  ...
# 3484                            NaN  ...
# 115                             NaN  ...
# 107   5.4"                           ...
# 106   5.4"                           ...
# 120                             NaN  ...
# 130                             NaN  ...
# 128                             NaN  ...
# 131   4.7" - Tần số quét Hãng không  ...
# 111                             NaN  ...
# 3145  6.4" - Tần số quét 120 Hz      ...
# 108   5.4"                           ...
# 99    6.1"                           ...
# 109                             NaN  ...
# 117                             NaN  ...
# 104   6.1"                           ...
# 102   6.1"                           ...
# 3150  6.4" - Tần số quét 120 Hz      ...
# 98    6.1"                           ...
# 100   6.1"                           ...
# 3146  6.4" - Tần số quét 120 Hz      ...
# 1393                            NaN  ...
# 124                             NaN  ...
# 122                             NaN  ...
# 1726                            NaN  ...
# 1391                            NaN  ...
# 1413                            NaN  ...
# 434   2.4"                           ...
# 4785  6.67"                          ...
#
#                                                     sim  \
# 126    2 SIM (nano‑SIM và eSIM)                     ...
# 127    2 SIM (nano‑SIM và eSIM)                     ...
# 118    2 SIM (nano‑SIM và eSIM)                     ...
# 116    2 SIM (nano‑SIM và eSIM)                     ...
# 3484   2 SIM (nano‑SIM và eSIM)                     ...
# 115    2 SIM (nano‑SIM và eSIM)                     ...
# 107    2 SIM (nano‑SIM và eSIM)                     ...
# 106    2 SIM (nano‑SIM và eSIM)                     ...
# 120    2 SIM (nano‑SIM và eSIM)                     ...
# 130    2 SIM (nano‑SIM và eSIM)                     ...
# 128    2 SIM (nano‑SIM và eSIM)                     ...
# 131    Nano-SIM + eSIM                              ...
# 111    2 SIM (nano‑SIM và eSIM)                     ...
# 3145   2 SIM (Nano-SIM)                             ...
# 108    2 SIM (nano‑SIM và eSIM)                     ...
# 99     Nano-SIM + eSIM                              ...
# 109                                                 ...
# 117    2 SIM (nano‑SIM và eSIM)                     ...
# 104    2 SIM (nano‑SIM và eSIM)                     ...
# 102    2 SIM (nano‑SIM và eSIM)                     ...
# 3150                                                ...
# 98     Nano-SIM + eSIM                              ...
# 100    2 SIM (nano‑SIM và eSIM)                     ...
# 3146                                                ...
# 1393   2 SIM (Nano-SIM)                             ...
# 124    2 SIM (nano‑SIM và eSIM)                     ...
# 122    2 SIM (nano‑SIM và eSIM)                     ...
# 1726   2 SIM (Nano-SIM)                             ...
# 1391   2 SIM (Nano-SIM)                             ...
# 1413   2 SIM (Nano-SIM)                             ...
# 434                                                 ...
# 4785   2 SIM (Nano-SIM)                             ...
#
#                                        operating_system  \
# 126    iOS15                                        ...
# 127    iOS15                                        ...
# 118    iOS15                                        ...
# 116    iOS15                                        ...
# 3484   Android 11                                   ...
# 115    iOS15                                        ...
# 107    iOS 14.1 hoặc cao hơn (Tùy vào phiên bản phát...
# 106    iOS 14.1 hoặc cao hơn (Tùy vào phiên bản phát...
# 120    iOS15                                        ...
# 130    iOS15                                        ...
# 128    iOS 14.1 hoặc cao hơn (Tùy vào phiên bản phát...
# 131    iOS 13                                       ...
# 111     iOS 15                                      ...
# 3145                                                ...
# 108    iOS 14.1 hoặc cao hơn (Tùy vào phiên bản phát...
# 99     iOS 13 hoặc cao hơn (Tùy vào phiên bản phát h...
# 109     iOS 15                                      ...
# 117    iOS15                                        ...
# 104    iOS 14.1 hoặc cao hơn (Tùy vào phiên bản phát...
# 102    iOS 14.1 hoặc cao hơn (Tùy vào phiên bản phát...
# 3150                                                ...
# 98     iOS 13 hoặc cao hơn (Tùy vào phiên bản phát h...
# 100    iOS 14.1 hoặc cao hơn (Tùy vào phiên bản phát...
# 3146                                                ...
# 1393   Android 11 (Go edition)                      ...
# 124    iOS15                                        ...
# 122    iOS 14.1 hoặc cao hơn (Tùy vào phiên bản phát...
# 1726   ColorOS 11.2  nền tảng Android 11            ...
# 1391   Android 11 (Go edition)                      ...
# 1413   Android 11 (Go edition)                      ...
# 434                                                 ...
# 4785   Android 11  MIUI 12                          ...
#
#                                              resolution  \
# 126    2778 x 1284 pixel                            ...
# 127    2778 x 1284 pixel                            ...
# 118    1170 x 2532 pixels                           ...
# 116    1080 x 2340 pixels (FullHD+)                 ...
# 3484                                                ...
# 115    1080 x 2340 pixels (FullHD+)                 ...
# 107    1080 x 2340 pixels (FullHD+)                 ...
# 106    1080 x 2340 pixels (FullHD+)                 ...
# 120    1170 x 2532 pixels                           ...
# 130    2778 x 1284 pixel                            ...
# 128    1284 x 2778 pixels                           ...
# 131    750 x 1334 pixels                            ...
# 111    2532 x 1170 pixels                           ...
# 3145   1080 x 2400 pixels (FullHD+)                 ...
# 108    1080 x 2340 pixels (FullHD+)                 ...
# 99     1792 x 828 pixel                             ...
# 109    2532 x 1170 pixels                           ...
# 117    1080 x 2340 pixels (FullHD+)                 ...
# 104    1170 x 2532 pixels                           ...
# 102    1170 x 2532 pixels                           ...
# 3150   1080 x 2400 pixels (FullHD+)                 ...
# 98     1792 x 828 pixel                             ...
# 100    1170 x 2532 pixels                           ...
# 3146   1080 x 2400 pixels (FullHD+)                 ...
# 1393   720 x 1600 pixel                             ...
# 124    1170 x 2532 pixels                           ...
# 122    1170 x 2532 pixels                           ...
# 1726   1440 x 3216 pixels (QHD+)                    ...
# 1391   720 x 1600 pixel                             ...
# 1413   720 x 1600 pixel                             ...
# 434    240 x 320 pixels                             ...
# 4785   1080 x 2400 pixels (FullHD+)                 ...
#
#                                         display_feature  \
# 126    120Hz  Super Retina XDR với ProMotion 6.1‑inc...
# 127    120Hz  Super Retina XDR với ProMotion 6.1‑inc...
# 118    120Hz  Super Retina XDR với ProMotion 6.1‑inc...
# 116    Màn hình super Retina XDR  OLED  476 ppi  HDR...
# 3484   Màn hình chính: 6.7" 2640 x 1080 425ppi   FHD...
# 115    Màn hình super Retina XDR  OLED  476 ppi  HDR...
# 107    Li-Ion  sạc nhanh 20W  sạc không dây 15W  USB...
# 106    HDR10Dolby VisionTrue-tone                   ...
# 120    120Hz  Super Retina XDR với ProMotion 6.1‑inc...
# 130    120Hz  Super Retina XDR với ProMotion 6.1‑inc...
# 128    HDR10Dolby VisionTrue-toneĐộ sáng 800 nits   ...
# 131    True-tone                                    ...
# 111    Màn hình super Retina XDR   OLED  460 ppi  HD...
# 3145   Trang bị Spen Pro                            ...
# 108    HDR10Dolby VisionTrue-tone                   ...
# 99     True-tone                                    ...
# 109    Màn hình super Retina XDR   OLED  460 ppi  HD...
# 117    Màn hình super Retina XDR  OLED  476 ppi  HDR...
# 104    HDR10Dolby VisionTrue-tone                   ...
# 102    HDR10Dolby VisionTrue-tone                   ...
# 3150   Trang bị Spen Pro                            ...
# 98     True-tone                                    ...
# 100    HDR10Dolby VisionTrue-tone                   ...
# 3146   Trang bị Spen Pro                            ...
# 1393                                                ...
# 124    120Hz  Super Retina XDR với ProMotion 6.1‑inc...
# 122    HDR10Dolby VisionTrue-tone                   ...
# 1726   Tần số quét 120Hz  hiển thị 1 tỷ màu  độ sáng...
# 1391                                                ...
# 1413                                                ...
# 434                                                 ...
# 4785   Hỗ trợ hiển thị 10 tỷ màu  tần số quét 120Hz ...
#
#                                                cpu_type  \
# 126                                                 ...
# 127                                                 ...
# 118                                                 ...
# 116                                                 ...
# 3484   1 nhân 2.84 GHz  3 nhân 2.42 GHz & 4 nhân 1.8...
# 115                                                 ...
# 107    Hexa-core                                    ...
# 106    Hexa-core                                    ...
# 120                                                 ...
# 130                                                 ...
# 128    Hexa-core                                    ...
# 131    2 nhân 2.65 GHz & 4 nhân 1.8 GHz             ...
# 111                                                 ...
# 3145                                                ...
# 108    Hexa-core                                    ...
# 99     Hexa-core                                    ...
# 109                                                 ...
# 117                                                 ...
# 104    Hexa-core                                    ...
# 102    Hexa-core                                    ...
# 3150                                                ...
# 98     Hexa-core                                    ...
# 100    Hexa-core                                    ...
# 3146                                                ...
# 1393   4x1.6 GHz Cortex-A55 & 4x1.2 GHz Cortex-A55  ...
# 124                                                 ...
# 122    Hexa-core                                    ...
# 1726   8 nhân (1x2.84 GHz Kryo 680 & 3x2.42 GHz Kryo...
# 1391   4x1.6 GHz Cortex-A55 & 4x1.2 GHz Cortex-A55  ...
# 1413   4x1.6 GHz Cortex-A55 & 4x1.2 GHz Cortex-A55  ...
# 434                                                 ...
# 4785   8 nhân ( 2x2.3 GHz Kryo 470 Gold & 6x1.8 GHz ...
#
#                                                  weight monitor_frequency  \
# 126    240g                                         ...               120
# 127    240g                                         ...               120
# 118    204g                                         ...               120
# 116    141g                                         ...                60
# 3484   183g                                         ...               120
# 115    141g                                         ...                60
# 107    135 g                                        ...                60
# 106    135 g                                        ...                60
# 120    204g                                         ...               120
# 130    240g                                         ...               120
# 128    228                                          ...                60
# 131    148 g                                        ...                60
# 111    174g                                         ...                60
# 3145                                                ...               120
# 108    135 g                                        ...
# 99     194 g                                        ...                60
# 109    174g                                         ...                60
# 117    141g                                         ...                60
# 104    164 g                                        ...                60
# 102    164 g                                        ...                60
# 3150                                                ...
# 98     194 g                                        ...                60
# 100    164 g                                        ...                60
# 3146                                                ...
# 1393   178 g                                        ...
# 124    204g                                         ...               120
# 122    189 g                                        ...                60
# 1726   193 g                                        ...               120
# 1391   178 g                                        ...
# 1413   178 g                                        ...
# 434    92 g                                         ...
# 4785   193 g                                        ...               120
#
#                                                  cpu  \
# 126    Apple A15
# 127    Apple A15
# 118    Apple A15
# 116    Apple A15 Bionic 6 nhân
# 3484   Snapdragon 888 8 (5nm)
# 115    Apple A15 Bionic 6 nhân
# 107    Apple A14 Bionic (5 nm)
# 106    Apple A14 Bionic (5 nm)
# 120    Apple A15
# 130    Apple A15
# 128    Apple A14 Bionic (5 nm)
# 131    Apple A13 Bionic 6 nhân
# 111    Apple A15
# 3145   Exynos 2100 (5nm)
# 108    Apple A14 Bionic (5 nm)
# 99     A13 Bionic
# 109    Apple A15
# 117    Apple A15
# 104    Apple A14 Bionic (5 nm)
# 102    Apple A14 Bionic (5 nm)
# 3150   Exynos 2100 (5nm)
# 98     A13 Bionic
# 100    Apple A14 Bionic (5 nm)
# 3146   Exynos 2100 (5nm)
# 1393   Unisoc SC9863A
# 124    Apple A15
# 122    Apple A14 Bionic (5 nm)
# 1726   Snapdragon 888 (5 nm)
# 1391   Unisoc SC9863A
# 1413   Unisoc SC9863A
# 434
# 4785   Snapdragon 732G (8 nm)
#
#                                    bluetooth image_right
# 126    v5.0                                          NaN
# 127    v5.0                                          NaN
# 118    v5.0                                          NaN
# 116    v5.0                                          NaN
# 3484   v 5.1                                         NaN
# 115    v5.0                                          NaN
# 107    5.0  A2DP  LE                                 NaN
# 106    5.0  A2DP  LE                                 NaN
# 120    v5.0                                          NaN
# 130    v5.0                                          NaN
# 128    5.0  A2DP  LE                                 NaN
# 131    A2DP  LE  v4.2                                NaN
# 111    v5.0                                          NaN
# 3145   5.2  A2DP  LE                                 NaN
# 108    5.0  A2DP  LE                                 NaN
# 99     5.0                                           NaN
# 109    v5.0                                          NaN
# 117    v5.0                                          NaN
# 104    5.0  A2DP  LE                                 NaN
# 102    5.0  A2DP  LE                                 NaN
# 3150   5.2  A2DP  LE                                 NaN
# 98     5.0                                           NaN
# 100    5.0  A2DP  LE                                 NaN
# 3146   5.2  A2DP  LE                                 NaN
# 1393   4.2  A2DP                                     NaN
# 124    v5.0                                          NaN
# 122    5.0  A2DP  LE                                 NaN
# 1726   5.2  A2DP  LE  aptX HD                        NaN
# 1391   4.2  A2DP                                     NaN
# 1413   4.2  A2DP                                     NaN
# 434    2.0                                           NaN
# 4785   5.1  A2DP  LE                                 NaN
#
# [32 rows x 39 columns]

# %%
warehouse = data_maping(nk, warehouse, mapping_nk, 0.1)

# %%
warehouse['phones']
# Out:
#       id                                            name  \
# 0      0     Apple iPhone 8 64GB Chính hãng
# 1      1     iPhone XR 128GB I Chính hãng VN/A
# 2      2     iPhone XR 64GB I Chính hãng VN/A
# 3      3     ASUS 8z
# 4      4     ASUS ROG Phone 2 512GB
# ..   ...                                             ...
# 657  657              Điện thoại iPhone 12 Pro 256GB Xám
# 658  658                   Điện thoại iPhone 12 128GB Đỏ
# 659  659             Điện thoại iPhone 12 Pro 256GB Xanh
# 660  660               Điện thoại iPhone 12 64GB Xanh lá
# 661  661  Điện thoại Samsung Galaxy A52 4G 8GB/128GB Tím
#
#                  display_size  \
# 0     4.7 inches
# 1     6.1 inches
# 2     6.1 inches
# 3     5.9 inches
# 4     6.59 inches
# ..                        ...
# 657                    6.1 "
# 658               6.1 inch "
# 659                    6.1 "
# 660               6.1 inch "
# 661                    6.5 "
#
#                                           display_tech  \
# 0                                                  ...
# 1     IPS LCD                                      ...
# 2     IPS LCD                                      ...
# 3     AMOLED                                       ...
# 4                                                  ...
# ..                                                 ...
# 657                                                NaN
# 658                                  Super Retina XDR
# 659                                                NaN
# 660                                  Super Retina XDR
# 661   Màn hình tràn viền vô cực Super AMOLED Full H...
#
#                                                 camera  \
# 0     12 MP (f/1.8  28mm)  tự động lấy nét nhận diệ...
# 1     12MP                                         ...
# 2     12MP                                         ...
# 3     Camera chính: 64 MP  f/1.73  16 MP           ...
# 4     48 MP + 13 MP                                ...
# ..                                                 ...
# 657                               12 MP  12 MP  12 MP
# 658                                       12 MP (kép)
# 659                               12 MP  12 MP  12 MP
# 660                                       12 MP (kép)
# 661                    4 camera 64MP+12MP + 5MP + 5MP
#
#                                          camera_selfie ram  rom battery  \
# 0     7 MP  f/2.2  1080p@30fps  720p@240fps  nhận d...       64    1821
# 1     7MP                                          ...   3  128    2942
# 2     7MP                                          ...   3   64    2942
# 3     12 MP                                        ...   8  128    4000
# 4     24 MP                                        ...  12  512  600040
# ..                                                 ...  ..  ...     ...
# 657                                             12 MP    6  256
# 658                                             12 MP    4  128
# 659                                             12 MP    6  256
# 660                                              12MP    4   64
# 661                                              32MP    8  128
#
#                                                    sim  \
# 0     Nano-SIM                                     ...
# 1     Nano-SIM                                     ...
# 2     Nano-SIM                                     ...
# 3     2 SIM (Nano-SIM)                             ...
# 4     Nano-SIM                                     ...
# ..                                                 ...
# 657                                                NaN
# 658                                                NaN
# 659                                                NaN
# 660                                                NaN
# 661                                                NaN
#
#                                       operating_system  \
# 0     11                                           ...
# 1     iOS 12                                       ...
# 2     iOS 14                                       ...
# 3     Android 11                                   ...
# 4     Android 9.0 (Pie)                            ...
# ..                                                 ...
# 657                                          iOS 14.1
# 658                                          iOS 14.1
# 659                                          iOS 14.1
# 660                                          iOS 14.1
# 661                                                NaN
#
#                                             resolution  \
# 0     750 x 1334 pixels                            ...
# 1     1792 x 828 pixel                             ...
# 2     1792 x 828 pixel                             ...
# 3     1080 x 2400 pixels (FullHD+)                 ...
# 4     1080 x 2340 pixels (FullHD+)                 ...
# ..                                                 ...
# 657                                                NaN
# 658                                2532 x 1170 pixels
# 659                                                NaN
# 660                                2532 x 1170 pixels
# 661                                                NaN
#
#                                        display_feature  \
# 0                                                  ...
# 1     True-tone                                    ...
# 2     True-tone  tần số quét 60Hz  mật độ điểm ảnh ...
# 3     Độ sáng tối đa 1100 nits  112% DCI-P3  107% N...
# 4                                                  ...
# ..                                                 ...
# 657
# 658
# 659
# 660
# 661
#
#                                               cpu_type  \
# 0     2x 2.39 GHz Monsoon & 4x 2.39 GHz Mistral    ...
# 1     Hexa-core                                    ...
# 2     Hexa-core                                    ...
# 3                                                  ...
# 4     64-bit Octa-core                             ...
# ..                                                 ...
# 657
# 658
# 659
# 660
# 661
#
#                                                 weight monitor_frequency  \
# 0     148 g (5.22 oz)                              ...
# 1     194 g                                        ...                60
# 2     194 g                                        ...                60
# 3     169 g                                        ...               120
# 4     240 g                                        ...               120
# ..                                                 ...               ...
# 657
# 658
# 659
# 660
# 661
#
#                                                 cpu  \
# 0     Apple A11 Bionic APL1W72
# 1     Apple A12 Bionic
# 2     Apple A12 Bionic
# 3     Qualcomm® Snapdragon™ 888 5G
# 4     Snapdragon 855 Plus Mobile Platform
# ..                                              ...
# 657                               Apple A14 Bionic
# 658                               Apple A14 Bionic
# 659                               Apple A14 Bionic
# 660                               Apple A14 Bionic
# 661                Vi xử lý 8 nhân Snapdragon 720G
#
#                                   bluetooth  \
# 0     5.0  A2DP  LE
# 1     v5.0  A2DP  LE
# 2     v5.0  A2DP  LE
# 3     5.2 (EDR + A2DP)  hỗ trợ LDAC  Qualco
# 4     V 5.0 (BR/EDR+LE)  hỗ trợ Qualcomm® a
# ..                                      ...
# 657                                     NaN
# 658                          Bluetooth 5.0
# 659                                     NaN
# 660                         Bluetooth 5.0
# 661                                     NaN
#
#                                                  image
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 657  https://www.nguyenkim.com/dien-thoai-iphone-12...
# 658  https://www.nguyenkim.com/dien-thoai-iphone-12...
# 659  https://www.nguyenkim.com/dien-thoai-iphone-12...
# 660  https://www.nguyenkim.com/dien-thoai-iphone-12...
# 661  https://www.nguyenkim.com/dien-thoai-samsung-g...
#
# [662 rows x 19 columns]
